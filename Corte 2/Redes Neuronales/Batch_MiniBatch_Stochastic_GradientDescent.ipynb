# %% [markdown]
# # Red convolucional básica.
#
#
# Una de las técnicas más usadas para estimar los parámetros de una red neuronal es el gradiente descendente, el cual es un algoritmo iterativo donde el valor de los parámetros en la iteración actual depende del valor en la iteración pasada y del valor de los gradientes.
#
#
# $$w^{(t)} = w^{(t-1)} - \eta\frac{\partial J(w)}{\partial w},$$
#
#
# donde $\eta$ es el factor de aprendizaje y $J(w)$ es la función de pérdida. El cálculo de las derivadas se hace a partir de los datos de entrenamiento y dependiendo de la proporción de los datos de datos entrenamiento que usemos en dicho cálculo, se reconocen tres enfoques:
#
#
# 1. Gradiente descendente por lotes.
# 2. Gradiente descendente estocástico.
# 3. Gradiente descendente por mini-lotes.
#
#
# En este documento explicaremos, a partir de un ejemplo práctico, las principales ventajas y desventajas de cada enfoque.
#
#
#
# ## Etapa 1: Definición de los datos.
#
#
# Antes de comenzar con el estudio de los tres enfoques de optimización, definimos la base de datos de interés. Para este caso particular, usaremos una base de datos sintética con dos atributos y que configura un problema de clasificación con 3 clases ([Ver enlace](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html))

# %% [markdown]
# Se cargan las librerías necesarias

# %%
import tensorflow as tf
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.utils.vis_utils import plot_model
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %% [markdown]
# Se crea la base de datos y se divide en los conjuntos de entrenamiento y prueba. Se definen 1000 muestras de las cuales el 80% se usa en el entrenamiento y el 20% restante para el conjunto de prueba.

# %%
n = 1000
classes = 3
dimensions = 2

train_size = int(n * 0.8)

X, y = make_blobs(
    n_samples=n, 
    centers=classes, 
    n_features=dimensions,
    cluster_std=2,
    random_state=42
)

x_train, x_test = X[:train_size,:], X[train_size:,:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
print(x_train.shape)
# Out:
# (800, 2)

# %% [markdown]
# Ahora escribiremos algunas funciones que nos serán útiles para definir y entrenar el modelo de redes neuronales. Se llevarán a cabo tres experimentos (uno por cada enfoque de optimización) que usarán exactamente la misma red, lo único que se varía es el enfoque de optimización.

# %%
# Esta función permite definir y entrenar una red neuronal. La función tiene dos 
# argumentos de entrada. El primero es el tamaño del lote; el segundo, es el tipo 
# de optimización que se usará para el entrenamiento.
def fit_model(batch_size):
    # Se define una red con un única capa oculta con 32 unidades y activación ReLU.
    model = Sequential([
        Dense(32, input_dim=dimensions, activation="relu"),
        Dense(classes, activation="softmax")
    ])

    # Se compila el modelo usando un optimizador basado en gradiente descendente
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.90), 
        loss="sparse_categorical_crossentropy", 
        metrics=["accuracy"]
    )

    history = model.fit(
        x_train, 
        y_train, 
        validation_data=(x_test, y_test), 
        epochs=100, 
        batch_size=batch_size
    )

    return model, history


def evaluate(model, history):
    # Se evalúa el accuracy del modelo tanto en el conjunto de entrenamiento como 
    # en el de prueba.
    _, train_accuracy = model.evaluate(x_train, y_train)
    _, test_accuracy = model.evaluate(x_test, y_test)

    print(f"Trainining accuracy: {train_accuracy:.2f}")
    print(f"Testing accuracy: {test_accuracy:.2f}")

    # Se grafica la función de pérdida para los conjuntos de entrenamiento y 
    # prueba.
    plt.figure(figsize=(6, 4), dpi=160)

    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="test")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Etapa 2: Gradiente descendente por lotes.
#
# En este primer enfoque corresponde al gradiente descendente por lotes. En este método de optimización se usan todos los datos disponibles en el conjunto de entrenamiento. En nuestro caso particular, el conjunto entrenamiento está compuesto por 800 muestras, así definimos:
# `batch_size = 800`.
#
# En este caso, dado que en cada iteración de la optimización se usan todos los datos del entrenamiento, el parámetro `epochs`, usado en el `model.fit`, indica la cantidad de iteraciones de la fase de entrenamiento.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1 

model, history = fit_model(batch_size=800)
evaluate(model, history)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 7s 7s/step - loss: 2.1603 - accuracy: 0.1262 - val_loss: 1.8235 - val_accuracy: 0.2200
# Epoch 2/100
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7666 - accuracy: 0.2163 - val_loss: 1.2412 - val_accuracy: 0.4300
# Epoch 3/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.1925 - accuracy: 0.4625 - val_loss: 0.7736 - val_accuracy: 0.6450
# Epoch 4/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7437 - accuracy: 0.6562 - val_loss: 0.4711 - val_accuracy: 0.6600
# Epoch 5/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4562 - accuracy: 0.6675 - val_loss: 0.2727 - val_accuracy: 0.9800
# Epoch 6/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2692 - accuracy: 0.9638 - val_loss: 0.1621 - val_accuracy: 0.9950
# Epoch 7/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1677 - accuracy: 0.9912 - val_loss: 0.1116 - val_accuracy: 0.9950
# Epoch 8/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1236 - accuracy: 0.9850 - val_loss: 0.0912 - val_accuracy: 0.9950
# Epoch 9/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1082 - accuracy: 0.9737 - val_loss: 0.0829 - val_accuracy: 0.9850
# Epoch 10/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1040 - accuracy: 0.9675 - val_loss: 0.0776 - val_accuracy: 0.9800
# Epoch 11/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1018 - accuracy: 0.9650 - val_loss: 0.0715 - val_accuracy: 0.9750
# Epoch 12/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0974 - accuracy: 0.9650 - val_loss: 0.0636 - val_accuracy: 0.9800
# Epoch 13/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0899 - accuracy: 0.9650 - val_loss: 0.0545 - val_accuracy: 0.9850
# Epoch 14/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0801 - accuracy: 0.9675 - val_loss: 0.0456 - val_accuracy: 0.9900
# Epoch 15/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0692 - accuracy: 0.9737 - val_loss: 0.0376 - val_accuracy: 0.9950
# Epoch 16/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0587 - accuracy: 0.9775 - val_loss: 0.0311 - val_accuracy: 0.9950
# Epoch 17/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0495 - accuracy: 0.9837 - val_loss: 0.0260 - val_accuracy: 0.9950
# Epoch 18/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0421 - accuracy: 0.9875 - val_loss: 0.0222 - val_accuracy: 0.9950
# Epoch 19/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.0195 - val_accuracy: 0.9950
# Epoch 20/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0323 - accuracy: 0.9887 - val_loss: 0.0177 - val_accuracy: 0.9950
# Epoch 21/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0296 - accuracy: 0.9900 - val_loss: 0.0166 - val_accuracy: 0.9950
# Epoch 22/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0278 - accuracy: 0.9925 - val_loss: 0.0160 - val_accuracy: 0.9950
# Epoch 23/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0159 - val_accuracy: 0.9950
# Epoch 24/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0262 - accuracy: 0.9950 - val_loss: 0.0160 - val_accuracy: 0.9950
# Epoch 25/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0261 - accuracy: 0.9950 - val_loss: 0.0162 - val_accuracy: 0.9950
# Epoch 26/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0262 - accuracy: 0.9937 - val_loss: 0.0166 - val_accuracy: 0.9950
# Epoch 27/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0264 - accuracy: 0.9937 - val_loss: 0.0170 - val_accuracy: 0.9950
# Epoch 28/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0266 - accuracy: 0.9937 - val_loss: 0.0174 - val_accuracy: 0.9900
# Epoch 29/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0268 - accuracy: 0.9937 - val_loss: 0.0176 - val_accuracy: 0.9900
# Epoch 30/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0178 - val_accuracy: 0.9900
# Epoch 31/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0272 - accuracy: 0.9925 - val_loss: 0.0179 - val_accuracy: 0.9900
# Epoch 32/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0272 - accuracy: 0.9925 - val_loss: 0.0179 - val_accuracy: 0.9900
# Epoch 33/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0272 - accuracy: 0.9925 - val_loss: 0.0178 - val_accuracy: 0.9900
# Epoch 34/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0176 - val_accuracy: 0.9900
# Epoch 35/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.0173 - val_accuracy: 0.9900
# Epoch 36/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0266 - accuracy: 0.9925 - val_loss: 0.0170 - val_accuracy: 0.9900
# Epoch 37/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0263 - accuracy: 0.9925 - val_loss: 0.0166 - val_accuracy: 0.9900
# Epoch 38/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.0161 - val_accuracy: 0.9900
# Epoch 39/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 0.0157 - val_accuracy: 0.9900
# Epoch 40/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0252 - accuracy: 0.9937 - val_loss: 0.0153 - val_accuracy: 0.9950
# Epoch 41/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0248 - accuracy: 0.9937 - val_loss: 0.0148 - val_accuracy: 0.9950
# Epoch 42/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0244 - accuracy: 0.9937 - val_loss: 0.0144 - val_accuracy: 0.9950
# Epoch 43/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0140 - val_accuracy: 0.9950
# Epoch 44/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0238 - accuracy: 0.9950 - val_loss: 0.0137 - val_accuracy: 0.9950
# Epoch 45/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0235 - accuracy: 0.9937 - val_loss: 0.0133 - val_accuracy: 0.9950
# Epoch 46/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 47/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0230 - accuracy: 0.9950 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 48/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0228 - accuracy: 0.9950 - val_loss: 0.0125 - val_accuracy: 0.9950
# Epoch 49/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0227 - accuracy: 0.9950 - val_loss: 0.0124 - val_accuracy: 0.9950
# Epoch 50/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 51/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0225 - accuracy: 0.9950 - val_loss: 0.0121 - val_accuracy: 0.9950
# Epoch 52/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0224 - accuracy: 0.9950 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 53/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.0119 - val_accuracy: 0.9950
# Epoch 54/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0118 - val_accuracy: 0.9950
# Epoch 55/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0117 - val_accuracy: 0.9950
# Epoch 56/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0117 - val_accuracy: 0.9950
# Epoch 57/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0117 - val_accuracy: 0.9950
# Epoch 58/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 59/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 60/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 61/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 62/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 63/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 64/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 65/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 66/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 67/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 68/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 69/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 70/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 71/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 72/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 73/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 74/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 75/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 76/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 77/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 78/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 79/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 80/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 81/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 82/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 83/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 84/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 85/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 86/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 87/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 88/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 89/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 90/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0215 - accuracy: 0.9950 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 91/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0215 - accuracy: 0.9950 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 92/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 93/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 94/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 95/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 96/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 97/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 98/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0213 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 99/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0213 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 100/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0213 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9950
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9950
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9950
# Trainining accuracy: 1.00
# Testing accuracy: 1.00
# 20 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 3. Gradiente descendente estocástico.
#
# En el gradiente descendente estocástico, una época se considera completa cuando todos los datos de entrenamiento han sido utilizados en la optimización de la red neuronal. En este caso, como en cada iteración se usa una sola muestra, una época se completa en un número de iteraciones igual al tamaño del conjunto de entrenamiento, que en este caso es de 800 iteraciones.Àdemas, dado que el parámetro `epochs` está fijado en 100, el entrenamiento de la red se llevará a cabo 80000 iteraciones.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1 

model, history = fit_model(batch_size=1)
evaluate(model, history)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.1016 - accuracy: 0.9787 - val_loss: 0.0221 - val_accuracy: 0.9950
# Epoch 2/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0181 - val_accuracy: 0.9900
# Epoch 3/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0329 - accuracy: 0.9875 - val_loss: 0.0406 - val_accuracy: 0.9850
# Epoch 4/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0389 - accuracy: 0.9912 - val_loss: 0.0203 - val_accuracy: 0.9900
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0338 - accuracy: 0.9887 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 6/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0348 - accuracy: 0.9900 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 7/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 8/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.0234 - val_accuracy: 0.9850
# Epoch 9/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0288 - accuracy: 0.9912 - val_loss: 0.0076 - val_accuracy: 0.9950
# Epoch 10/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0529 - accuracy: 0.9825 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0267 - accuracy: 0.9900 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 13/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0375 - accuracy: 0.9900 - val_loss: 0.0118 - val_accuracy: 0.9950
# Epoch 14/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0246 - accuracy: 0.9887 - val_loss: 0.0215 - val_accuracy: 0.9950
# Epoch 15/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0419 - accuracy: 0.9887 - val_loss: 0.0086 - val_accuracy: 0.9950
# Epoch 16/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0307 - accuracy: 0.9875 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 17/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0423 - accuracy: 0.9887 - val_loss: 0.0506 - val_accuracy: 0.9650
# Epoch 18/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0648 - accuracy: 0.9825 - val_loss: 0.1762 - val_accuracy: 0.8450
# Epoch 19/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0339 - accuracy: 0.9912 - val_loss: 0.0232 - val_accuracy: 0.9850
# Epoch 20/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0396 - accuracy: 0.9900 - val_loss: 0.0100 - val_accuracy: 0.9950
# Epoch 21/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.0231 - val_accuracy: 0.9900
# Epoch 22/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0500 - accuracy: 0.9912 - val_loss: 0.0285 - val_accuracy: 0.9850
# Epoch 23/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0299 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 0.9950
# Epoch 24/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0284 - accuracy: 0.9925 - val_loss: 0.0162 - val_accuracy: 0.9950
# Epoch 25/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0320 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 0.9950
# Epoch 26/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 27/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0292 - accuracy: 0.9862 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 28/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 29/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0264 - accuracy: 0.9900 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 30/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0656 - val_accuracy: 0.9850
# Epoch 31/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0311 - accuracy: 0.9912 - val_loss: 0.0123 - val_accuracy: 0.9950
# Epoch 32/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0236 - accuracy: 0.9912 - val_loss: 0.0080 - val_accuracy: 0.9950
# Epoch 33/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.0301 - val_accuracy: 0.9850
# Epoch 34/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0276 - accuracy: 0.9912 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 35/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.0288 - accuracy: 0.9925 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 36/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 0.0530 - val_accuracy: 0.9850
# Epoch 37/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0217 - accuracy: 0.9912 - val_loss: 0.0118 - val_accuracy: 0.9950
# Epoch 38/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0313 - accuracy: 0.9912 - val_loss: 0.0199 - val_accuracy: 0.9950
# Epoch 39/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0207 - accuracy: 0.9912 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 40/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 41/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.0093 - val_accuracy: 0.9950
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0194 - accuracy: 0.9912 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 43/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 44/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0261 - accuracy: 0.9887 - val_loss: 0.0084 - val_accuracy: 0.9950
# Epoch 45/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0274 - accuracy: 0.9925 - val_loss: 0.0202 - val_accuracy: 0.9950
# Epoch 46/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 47/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.0297 - val_accuracy: 0.9950
# Epoch 48/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0193 - accuracy: 0.9925 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 49/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0234 - accuracy: 0.9937 - val_loss: 0.0150 - val_accuracy: 0.9950
# Epoch 50/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0287 - accuracy: 0.9875 - val_loss: 0.0127 - val_accuracy: 0.9950
# Epoch 51/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0248 - accuracy: 0.9937 - val_loss: 0.0147 - val_accuracy: 0.9950
# Epoch 52/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0271 - val_accuracy: 0.9850
# Epoch 53/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0347 - accuracy: 0.9912 - val_loss: 0.0066 - val_accuracy: 0.9950
# Epoch 54/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0145 - val_accuracy: 0.9900
# Epoch 55/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 56/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0159 - accuracy: 0.9937 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 57/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0270 - accuracy: 0.9937 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 58/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 59/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0244 - accuracy: 0.9950 - val_loss: 0.0137 - val_accuracy: 0.9950
# Epoch 60/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.0166 - val_accuracy: 0.9900
# Epoch 61/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0094 - val_accuracy: 0.9950
# Epoch 62/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 63/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0238 - accuracy: 0.9950 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 64/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0263 - val_accuracy: 0.9900
# Epoch 65/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0229 - val_accuracy: 0.9900
# Epoch 66/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0242 - accuracy: 0.9912 - val_loss: 0.0142 - val_accuracy: 0.9900
# Epoch 67/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0196 - accuracy: 0.9912 - val_loss: 0.0118 - val_accuracy: 0.9900
# Epoch 68/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0220 - accuracy: 0.9900 - val_loss: 0.0105 - val_accuracy: 0.9900
# Epoch 69/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.0243 - val_accuracy: 0.9950
# Epoch 70/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0087 - val_accuracy: 0.9950
# Epoch 71/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0071 - val_accuracy: 0.9950
# Epoch 72/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 73/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.0227 - val_accuracy: 0.9900
# Epoch 74/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0197 - accuracy: 0.9925 - val_loss: 0.0290 - val_accuracy: 0.9950
# Epoch 75/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0208 - accuracy: 0.9900 - val_loss: 0.0404 - val_accuracy: 0.9850
# Epoch 76/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 77/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0244 - accuracy: 0.9900 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 78/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.0104 - val_accuracy: 0.9950
# Epoch 79/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0206 - accuracy: 0.9912 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 80/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 0.0130 - val_accuracy: 0.9950
# Epoch 81/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0199 - accuracy: 0.9912 - val_loss: 0.0083 - val_accuracy: 0.9950
# Epoch 82/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0220 - accuracy: 0.9900 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 83/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0343 - val_accuracy: 0.9900
# Epoch 84/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.0593 - val_accuracy: 0.9650
# Epoch 85/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.0124 - val_accuracy: 0.9900
# Epoch 86/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.0137 - val_accuracy: 0.9950
# Epoch 87/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0097 - val_accuracy: 0.9950
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0170 - accuracy: 0.9925 - val_loss: 0.0263 - val_accuracy: 0.9850
# Epoch 89/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0244 - accuracy: 0.9912 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 90/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0228 - accuracy: 0.9912 - val_loss: 0.0128 - val_accuracy: 0.9900
# Epoch 92/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 93/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0214 - accuracy: 0.9912 - val_loss: 0.0089 - val_accuracy: 0.9950
# Epoch 94/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0244 - accuracy: 0.9862 - val_loss: 0.0123 - val_accuracy: 0.9900
# Epoch 95/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.0185 - val_accuracy: 0.9850
# Epoch 96/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0225 - accuracy: 0.9912 - val_loss: 0.0117 - val_accuracy: 0.9900
# Epoch 97/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 0.0112 - val_accuracy: 0.9900
# Epoch 98/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.0223 - val_accuracy: 0.9900
# Epoch 99/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 100/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.0083 - val_accuracy: 0.9950
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9937
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9950
# Trainining accuracy: 0.99
# Testing accuracy: 1.00
# 4min 22s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 4. Gradiente descendente por mini-lotes.
#
# Este último enfoque plantea un punto intermedio entre la optimización estocástica y la optimización por lotes. En este algoritmo de optimización por mini-lotes, el conjunto de entrenamiento se divide de forma aleatoria en conjuntos con tamaño `batch_size`. Se debe tener en cuenta que el valor `batch_size` es elegido por el usuario, así que se convierte en un nuevo hiper-parámetro de las redes neuronales.
#
# Siguiendo el análisis de los enfoques anteriores, para el método de gradiente descendente por mini-lotes, una época se completa en $\frac{N}{batch\_size}$ iteraciones, donde $N$ es el tamaño del conjunto de entrenamiento. De esta manera, el entrenamiento se se lleva a cabo en $epochs*\frac{N}{batch\_size}$ iteraciones.

# %%
# Se mide el tiempo de ejecución
# %%timeit -n 1 -r 1 

model, history = fit_model(batch_size=32)
evaluate(model, history)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 10ms/step - loss: 0.2013 - accuracy: 0.9175 - val_loss: 0.0178 - val_accuracy: 0.9950
# Epoch 2/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0125 - val_accuracy: 0.9950
# Epoch 3/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.0118 - val_accuracy: 0.9950
# Epoch 4/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.0118 - val_accuracy: 0.9950
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9950 - val_loss: 0.0114 - val_accuracy: 0.9950
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 7/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 8/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.0109 - val_accuracy: 0.9950
# Epoch 9/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.0105 - val_accuracy: 0.9950
# Epoch 10/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.0106 - val_accuracy: 0.9950
# Epoch 11/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9950 - val_loss: 0.0104 - val_accuracy: 0.9950
# Epoch 12/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9950 - val_loss: 0.0101 - val_accuracy: 0.9950
# Epoch 13/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 14/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9950 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 15/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9950 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 16/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 17/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9950 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 18/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 19/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9950 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 20/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.0101 - val_accuracy: 0.9950
# Epoch 21/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9950 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 23/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9950 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 24/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.0101 - val_accuracy: 0.9950
# Epoch 25/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9950 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 26/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 27/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 28/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 29/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 31/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9950 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 33/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 34/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 35/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9950 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 36/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 38/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 40/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9937 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9937 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 1.0000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9950
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Trainining accuracy: 1.00
# Testing accuracy: 1.00
# 14 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ## 4. Conclusiones
#
#
# ### 4.1 Gradiente estocástico por lotes.
# - Este método usa la totalidad de los datos de entrenamiento en cada iteración.
# - Como se nota en los resultados experimentales, la función de pérdida no presenta ruido.
# - La cantidad de iteraciones corresponde al parámetro `epochs`. Esta cantidad es la menor comparada con los otros dos enfoques.
# - Debido a que cada iteración de la optimización usa todos los datos de entrenamiento, este tipo de algoritmos puede presentar problemas en bases de datos con grandes cantidades de muestras o que contienen datos como imágenes o videos. La cantidad de los datos puede desbordar la memoria de nuestros equipos y simplemente no se podría ejecutar el proceso de entrenamiento.
# - Otra desventaja es que dado que la función de pérdida no presenta ruido, este tipo de optimización es propenso a entregar soluciones que no son óptimas, lo cual afecta el rendimiento de las redes neuronales.
#
#
# ### 4.2 Gradiente descendente estocástico.
# - Este método usa una única muestra en cada iteración del entrenamiento, lo cual disminuye al máximo la posibilidad de desbordar la memoria, incluso en bases de datos grandes.
# - La principal desventaja es el ruido presente en la función de pérdida, lo cual causa que la pérdida pueda cambiar abruptamente de una iteración a otra. Este ruido en la función de pérdida causa que el algoritmo sea propenso a no encontrar la solución óptima.
# - Otra desventaja está en el tiempo de ejecución. Este algoritmo debe completar $epochs*N$ iteraciones, lo cual puede incrementar el tiempo de ejecución del algoritmo de optimización.
#
#
# ### 4.3 Gradiente descendente por mini-lotes.
# - Este enfoque es un punto intermedio entre los dos enfoques anteriores, no se usan tantas muestras como el gradiente por lotes ni tan pocas muestras como el gradiente estocástico.
# - Es el enfoque más usado para el entrenamiento de las redes neuronales. El ruido de la función de pérdida es pequeña, lo cual previene cambios abruptos en la pérdida y que se lleguen a soluciones que no son óptimas. Esto se puede notar en los resultados experimentales, donde el gradiente por mini-lotes obtiene el mejor rendimiento con el menor tiempo de ejecución.
# - El gran problema relacionado con este enfoque es que tenemos un nuevo hiper-parámetro por ajustar, el tamaño del mini-lote (`batch_size`). Muchos experimentos en el área del aprendizaje profundo concluyen que la mejor elección es `batch_size` pequeño; de hecho, un buen valor por defecto es `batch_size = 32`.
# - Otro hiper-parámetro que hemos usado es el `momentum`. Este hiper-parámetro está relacionado con una modificación del algoritmo de gradiente descendente, que usa los conceptos estadísticos de la media móvil con el fin de disminuir las oscilaciones de la función de pérdida en los enfoques de gradiente estocástico y gradiente por mini-lotes. Un valor de `momentum` cercano a 1 presenta grandes oscilaciones. Por el contrario, un valor cercano a cero aumenta el suavizado de la función de costo; sin embargo, un valor de `momentum` muy pequeño puede llevar a soluciones que no son óptimas. Para más información se recomienda la siguiente [lectura](https://distill.pub/2017/momentum/) (opcional).
# - El algoritmo de gradiente descendente ha servido como base a nuevos optimizadores más robustos. Dentro de estos, el más usado en la actualidad es el algoritmo ADAM (adaptive moment estimation).
